# %% [markdown]
# # Matplotlib Library

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4]
y = [5,6,7,8]
c="r"
plt.plot(x,y,c)
plt.show()

# %%
x=[5,7,2,9,5]
y = [1,4,3,10,3]
c="r"
plt.plot(x,y,c)
plt.show()

# %%
x = [5,2,9,4,7]
y = [10,5,8,4,2]

plt.plot(x,y)
plt.plot(y, marker = 'o')
plt.show()
