# %% [markdown]
# # Voice Chatbot

# %%
pip install SpeechRecognition pyttsx3 wikipedia
# Out:
# Collecting SpeechRecognition
#   Downloading speechrecognition-3.17.0-py3-none-any.whl.metadata (28 kB)
# Collecting pyttsx3
#   Using cached pyttsx3-2.99-py3-none-any.whl.metadata (6.2 kB)
# Collecting wikipedia
#   Downloading wikipedia-1.4.0.tar.gz (27 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Requirement already satisfied: typing-extensions in c:\users\user\anaconda3\lib\site-packages (from SpeechRecognition) (4.15.0)
# Collecting standard-aifc (from SpeechRecognition)
#   Downloading standard_aifc-3.13.0-py3-none-any.whl.metadata (969 bytes)
# Collecting audioop-lts (from SpeechRecognition)
#   Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl.metadata (2.0 kB)
# Collecting comtypes (from pyttsx3)
#   Downloading comtypes-1.4.16-py3-none-any.whl.metadata (7.8 kB)
# Collecting pypiwin32 (from pyttsx3)
#   Using cached pypiwin32-223-py3-none-any.whl.metadata (236 bytes)
# Requirement already satisfied: pywin32 in c:\users\user\anaconda3\lib\site-packages (from pyttsx3) (311)
# Requirement already satisfied: beautifulsoup4 in c:\users\user\anaconda3\lib\site-packages (from wikipedia) (4.13.5)
# Requirement already satisfied: requests<3.0.0,>=2.0.0 in c:\users\user\anaconda3\lib\site-packages (from wikipedia) (2.32.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\anaconda3\lib\site-packages (from requests<3.0.0,>=2.0.0->wikipedia) (2026.6.17)
# Requirement already satisfied: soupsieve>1.2 in c:\users\user\anaconda3\lib\site-packages (from beautifulsoup4->wikipedia) (2.5)
# Collecting standard-chunk (from standard-aifc->SpeechRecognition)
#   Downloading standard_chunk-3.13.0-py3-none-any.whl.metadata (860 bytes)
# Downloading speechrecognition-3.17.0-py3-none-any.whl (32.9 MB)
#    ---------------------------------------- 0.0/32.9 MB ? eta -:--:--
#     --------------------------------------- 0.5/32.9 MB 3.4 MB/s eta 0:00:10
#    - -------------------------------------- 1.6/32.9 MB 4.1 MB/s eta 0:00:08
#    --- ------------------------------------ 2.6/32.9 MB 4.3 MB/s eta 0:00:08
#    ----- ---------------------------------- 4.2/32.9 MB 5.1 MB/s eta 0:00:06
#    ------- -------------------------------- 6.0/32.9 MB 5.8 MB/s eta 0:00:05
#    --------- ------------------------------ 7.6/32.9 MB 6.1 MB/s eta 0:00:05
#    ---------- ----------------------------- 8.7/32.9 MB 6.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 9.4/32.9 MB 5.7 MB/s eta 0:00:05
#    ----------- ---------------------------- 9.7/32.9 MB 5.4 MB/s eta 0:00:05
#    ------------ --------------------------- 10.2/32.9 MB 4.9 MB/s eta 0:00:05
#    ------------ --------------------------- 10.5/32.9 MB 4.7 MB/s eta 0:00:05
#    ------------- -------------------------- 11.0/32.9 MB 4.5 MB/s eta 0:00:05
#    -------------- ------------------------- 11.5/32.9 MB 4.3 MB/s eta 0:00:05
#    -------------- ------------------------- 12.1/32.9 MB 4.2 MB/s eta 0:00:05
#    --------------- ------------------------ 12.8/32.9 MB 4.0 MB/s eta 0:00:05
#    --------------- ------------------------ 13.1/32.9 MB 4.0 MB/s eta 0:00:05
#    ---------------- ----------------------- 13.6/32.9 MB 3.8 MB/s eta 0:00:06
#    ----------------- ---------------------- 14.2/32.9 MB 3.7 MB/s eta 0:00:05
#    ------------------ --------------------- 14.9/32.9 MB 3.7 MB/s eta 0:00:05
#    ------------------ --------------------- 15.5/32.9 MB 3.7 MB/s eta 0:00:05
#    ------------------- -------------------- 16.3/32.9 MB 3.6 MB/s eta 0:00:05
#    -------------------- ------------------- 16.8/32.9 MB 3.6 MB/s eta 0:00:05
#    --------------------- ------------------ 17.3/32.9 MB 3.5 MB/s eta 0:00:05
#    --------------------- ------------------ 17.8/32.9 MB 3.5 MB/s eta 0:00:05
#    ---------------------- ----------------- 18.4/32.9 MB 3.5 MB/s eta 0:00:05
#    ----------------------- ---------------- 19.1/32.9 MB 3.5 MB/s eta 0:00:04
#    ------------------------ --------------- 19.9/32.9 MB 3.4 MB/s eta 0:00:04
#    ------------------------ --------------- 20.4/32.9 MB 3.4 MB/s eta 0:00:04
#    ------------------------- -------------- 21.2/32.9 MB 3.4 MB/s eta 0:00:04
#    -------------------------- ------------- 22.0/32.9 MB 3.4 MB/s eta 0:00:04
#    --------------------------- ------------ 22.8/32.9 MB 3.4 MB/s eta 0:00:03
#    ---------------------------- ----------- 23.6/32.9 MB 3.4 MB/s eta 0:00:03
#    ----------------------------- ---------- 24.4/32.9 MB 3.5 MB/s eta 0:00:03
#    ------------------------------ --------- 24.9/32.9 MB 3.4 MB/s eta 0:00:03
#    ------------------------------- -------- 25.7/32.9 MB 3.4 MB/s eta 0:00:03
#    -------------------------------- ------- 26.5/32.9 MB 3.4 MB/s eta 0:00:02
#    --------------------------------- ------ 27.3/32.9 MB 3.5 MB/s eta 0:00:02
#    ---------------------------------- ----- 28.3/32.9 MB 3.5 MB/s eta 0:00:02
#    ----------------------------------- ---- 29.1/32.9 MB 3.5 MB/s eta 0:00:02
#    ------------------------------------ --- 30.1/32.9 MB 3.5 MB/s eta 0:00:01
#    ------------------------------------- -- 30.9/32.9 MB 3.5 MB/s eta 0:00:01
#    -------------------------------------- - 32.0/32.9 MB 3.5 MB/s eta 0:00:01
#    ---------------------------------------  32.8/32.9 MB 3.6 MB/s eta 0:00:01
#    ---------------------------------------- 32.9/32.9 MB 3.5 MB/s  0:00:09
# Using cached pyttsx3-2.99-py3-none-any.whl (32 kB)
# Downloading audioop_lts-0.2.2-cp313-abi3-win_amd64.whl (30 kB)
# Downloading comtypes-1.4.16-py3-none-any.whl (296 kB)
# Using cached pypiwin32-223-py3-none-any.whl (1.7 kB)
# Downloading standard_aifc-3.13.0-py3-none-any.whl (10 kB)
# Downloading standard_chunk-3.13.0-py3-none-any.whl (4.9 kB)
# Building wheels for collected packages: wikipedia
#   Building wheel for wikipedia (pyproject.toml): started
#   Building wheel for wikipedia (pyproject.toml): finished with status 'done'
#   Created wheel for wikipedia: filename=wikipedia-1.4.0-py3-none-any.whl size=11785 sha256=758dce51e19a3e61fd99d727873b3d71a20e301dd4bf83b53f7868eedde9d178
#   Stored in directory: c:\users\user\appdata\local\pip\cache\wheels\79\1d\c8\b64e19423cc5a2a339450ea5d145e7c8eb3d4aa2b150cde33b
# Successfully built wikipedia
# Installing collected packages: standard-chunk, pypiwin32, comtypes, audioop-lts, wikipedia, standard-aifc, pyttsx3, SpeechRecognition
#
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    ---------- ----------------------------- 2/8 [comtypes]
#    -------------------- ------------------- 4/8 [wikipedia]
#    ------------------------------ --------- 6/8 [pyttsx3]
#    ----------------------------------- ---- 7/8 [SpeechRecognition]
#    ----------------------------------- ---- 7/8 [SpeechRecognition]
#    ----------------------------------- ---- 7/8 [SpeechRecognition]
#    ----------------------------------- ---- 7/8 [SpeechRecognition]
#    ----------------------------------- ---- 7/8 [SpeechRecognition]
#    ---------------------------------------- 8/8 [SpeechRecognition]
#
# Successfully installed SpeechRecognition-3.17.0 audioop-lts-0.2.2 comtypes-1.4.16 pypiwin32-223 pyttsx3-2.99 standard-aifc-3.13.0 standard-chunk-3.13.0 wikipedia-1.4.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pyaudio
# Out:
# Collecting pyaudio
#   Downloading PyAudio-0.2.14-cp313-cp313-win_amd64.whl.metadata (2.7 kB)
# Downloading PyAudio-0.2.14-cp313-cp313-win_amd64.whl (173 kB)
# Installing collected packages: pyaudio
# Successfully installed pyaudio-0.2.14
# Note: you may need to restart the kernel to use updated packages.

# %%
import speech_recognition as sr
import pyttsx3
import wikipedia

engine = pyttsx3.init()

def speak(text):
    engine.say(text)
    engine.runAndWait()

recognizer = sr.Recognizer()

with sr.Microphone() as source:
    print("Listening...")
    audio = recognizer.listen(source)

try:
    command = recognizer.recognize_google(audio)
    print("You said:",command)

    result = wikipedia.summary(command, sentences=2)

    print(result)
    speak(result)

except:
    speak("Sorry, I could not understand")
# Out:
# Listening...
# You said: capital of India
# This is a list of locations which have served as capital cities in India. The current capital city is New Delhi, which replaced Calcutta in 1911.
